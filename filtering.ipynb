# %%
import pandas as pd

# %%
bios=pd.read_csv('./data/bios.csv')
coffee=pd.read_csv('./warmup-data/coffee.csv')

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.tail()
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country        NOC  height_cm  weight_kg  \
# 145495       Sverdlovsk          RUS        ROC      167.0       61.0
# 145496           Moskva          RUS        ROC      168.0       65.0
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# 145499  New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20

# %%
bios.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  str
#  2   born_date     143693 non-null  str
#  3   born_city     110908 non-null  str
#  4   born_region   110908 non-null  str
#  5   born_country  110908 non-null  str
#  6   NOC           145499 non-null  str
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   str
# dtypes: float64(2), int64(1), str(7)
# memory usage: 18.5 MB

# %%
bios.loc[bios["height_cm"]>215]
# Out:
#         athlete_id                   name   born_date               born_city  \
# 5089          5108     Viktor Pankrashkin  1957-06-19         Moskva (Moscow)
# 5583          5606   Paulinho Villas Boas  1963-01-26               São Paulo
# 5673          5696         Gunther Behnke  1963-01-19              Leverkusen
# 5716          5739               Uwe Blab  1962-03-26        München (Munich)
# 5781          5804         Tommy Burleson  1952-02-24               Crossnore
# 5796          5819          Andy Campbell  1956-07-21               Melbourne
# 6223          6250            Lars Hansen  1954-09-27  København (Copenhagen)
# 6270          6298            Hu Zhangbao  1963-04-05                     NaN
# 6409          6440       Sergey Kovalenko  1947-08-11                     NaN
# 6420          6451          Jānis Krūmiņš  1930-01-30                   Cēsis
# 6504          6537            Luc Longley  1969-01-19               Melbourne
# ...

# %%
bios.loc[(bios["height_cm"]>215)&(bios["born_country"]=='FRA'),['name','height_cm','born_country']]
# Out:
#                   name  height_cm born_country
# 82100    Frédéric Weis      218.0          FRA
# 139365  Moustapha Fall      218.0          FRA

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios.loc[
    (bios['height_cm']>200)&
    (bios['born_country']=='FRA')&
    (bios['born_city']=='Paris'),
    :
].sort_values(['height_cm','weight_kg'],ascending=[0,0])
# Out:
#         athlete_id              name   born_date born_city born_region  \
# 139365      142836    Moustapha Fall  1992-02-23     Paris       Paris
# 131168      133932   Nicolas Le Goff  1992-02-15     Paris       Paris
# 122605      124711  Yakhouba Diawara  1982-08-29     Paris       Paris
#
#        born_country     NOC  height_cm  weight_kg died_date
# 139365          FRA  France      218.0        NaN       NaN
# 131168          FRA  France      206.0      115.0       NaN
# 122605          FRA  France      201.0      102.0       NaN

# %%
bios.loc[
    bios['name'].str.contains("Keith")
]
# Out:
#         athlete_id                  name   born_date         born_city  \
# 1897          1907          Keith Hanlon  1966-09-01               NaN
# 3505          3517         Keith Wallace  1961-03-29           Preston
# 6228          6255         Keith Hartley  1940-10-15         Vancouver
# 8898          8946           Keith Mwila  1966-01-01               NaN
# 12053        12118          Keith Hervey  1898-11-03            Fulham
# ...            ...                   ...         ...               ...
# 109900      111105     Keith Cumberpatch  1927-08-25      Christchurch
# 115973      117348       Keith Sanderson  1975-02-02          Plymouth
# 117676      119195          Duncan Keith  1983-07-16          Winnipeg
# 122121      124176        Keith Ferguson  1979-09-07              Sale
# 127310      129749  Tracy Keith-Matchitt  1990-03-30  Palmerston North
#
#               born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
bios.loc[
    (bios['born_country'].isin(['USA','FRA','GBR'])&(bios['name'].str.contains('Keith')))
]
# Out:
#         athlete_id                name   born_date             born_city  \
# 3505          3517       Keith Wallace  1961-03-29               Preston
# 12053        12118        Keith Hervey  1898-11-03                Fulham
# 14577        14674      Keith Harrison  1933-03-28            Birmingham
# 16166        16281      Keith Reynolds  1963-12-25              Solihull
# 18734        18862      Keith Sinclair  1945-06-26            Sunderland
# 29897        30123       Keith Langley  1961-06-03             Aldershot
# 34011        34275        Keith Remfry  1947-11-17                Ealing
# 46885        47234        Keith Collin  1937-01-18            Marylebone
# 50929        51288        Keith Carter  1924-08-30                 Akron
# 51185        51544       Keith Russell  1948-01-15                  Mesa
# 52913        53288      Keith Erickson  1944-04-19         San Francisco
# 55317        55712        Keith Boxell  1958-05-06               Clapham
# ...

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee['Price']=4.99

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price
# 0     Monday    Espresso          25   4.99
# 1     Monday       Latte          15   4.99
# 2    Tuesday    Espresso          30   4.99
# 3    Tuesday       Latte          20   4.99
# 4  Wednesday    Espresso          35   4.99

# %%
import numpy as np 
coffee_new=coffee.copy()
coffee_new['New_Price']=np.where(coffee['Coffee Type']=='Espresso',150,100)

# %%
coffee_new.head()
# Out:
#          Day Coffee Type  Units Sold  Price  New_Price
# 0     Monday    Espresso          25   4.99        150
# 1     Monday       Latte          15   4.99        100
# 2    Tuesday    Espresso          30   4.99        150
# 3    Tuesday       Latte          20   4.99        100
# 4  Wednesday    Espresso          35   4.99        150

# %%
coffee_new.drop(2,inplace=True)

# %%
coffee_new.drop(columns=['Price'])
# Out:
#           Day Coffee Type  Units Sold  New_Price
# 0      Monday    Espresso          25        150
# 1      Monday       Latte          15        100
# 3     Tuesday       Latte          20        100
# 4   Wednesday    Espresso          35        150
# 5   Wednesday       Latte          25        100
# 6    Thursday    Espresso          40        150
# 7    Thursday       Latte          30        100
# 8      Friday    Espresso          45        150
# 9      Friday       Latte          35        100
# 10   Saturday    Espresso          45        150
# 11   Saturday       Latte          35        100
# 12     Sunday    Espresso          45        150
# 13     Sunday       Latte          35        100

# %%
coffee_new.drop(columns=['Price'], inplace=True)

# %%
coffee_new
# Out:
#           Day Coffee Type  Units Sold  New_Price
# 0      Monday    Espresso          25        150
# 1      Monday       Latte          15        100
# 3     Tuesday       Latte          20        100
# 4   Wednesday    Espresso          35        150
# 5   Wednesday       Latte          25        100
# 6    Thursday    Espresso          40        150
# 7    Thursday       Latte          30        100
# 8      Friday    Espresso          45        150
# 9      Friday       Latte          35        100
# 10   Saturday    Espresso          45        150
# 11   Saturday       Latte          35        100
# 12     Sunday    Espresso          45        150
# 13     Sunday       Latte          35        100

# %%
coffee_new.loc[2]=['Tuesday','Espresso','30','150']

# %%
coffee_new
# Out:
#           Day Coffee Type Units Sold New_Price
# 0      Monday    Espresso         25       150
# 1      Monday       Latte         15       100
# 3     Tuesday       Latte         20       100
# 4   Wednesday    Espresso         35       150
# 5   Wednesday       Latte         25       100
# 6    Thursday    Espresso         40       150
# 7    Thursday       Latte         30       100
# 8      Friday    Espresso         45       150
# 9      Friday       Latte         35       100
# 10   Saturday    Espresso         45       150
# 11   Saturday       Latte         35       100
# 12     Sunday    Espresso         45       150
# 13     Sunday       Latte         35       100
# 2     Tuesday    Espresso         30       150

# %%
coffee_new=coffee_new.sort_index()

# %%
coffee_new.head()
# Out:
#          Day Coffee Type Units Sold New_Price
# 0     Monday    Espresso         25       150
# 1     Monday       Latte         15       100
# 2    Tuesday    Espresso         30       150
# 3    Tuesday       Latte         20       100
# 4  Wednesday    Espresso         35       150

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price
# 0      Monday    Espresso          25   4.99
# 1      Monday       Latte          15   4.99
# 2     Tuesday    Espresso          30   4.99
# 3     Tuesday       Latte          20   4.99
# 4   Wednesday    Espresso          35   4.99
# 5   Wednesday       Latte          25   4.99
# 6    Thursday    Espresso          40   4.99
# 7    Thursday       Latte          30   4.99
# 8      Friday    Espresso          45   4.99
# 9      Friday       Latte          35   4.99
# 10   Saturday    Espresso          45   4.99
# 11   Saturday       Latte          35   4.99
# 12     Sunday    Espresso          45   4.99
# 13     Sunday       Latte          35   4.99

# %%
coffee_new
# Out:
#           Day Coffee Type Units Sold New_Price
# 0      Monday    Espresso         25       150
# 1      Monday       Latte         15       100
# 2     Tuesday    Espresso         30       150
# 3     Tuesday       Latte         20       100
# 4   Wednesday    Espresso         35       150
# 5   Wednesday       Latte         25       100
# 6    Thursday    Espresso         40       150
# 7    Thursday       Latte         30       100
# 8      Friday    Espresso         45       150
# 9      Friday       Latte         35       100
# 10   Saturday    Espresso         45       150
# 11   Saturday       Latte         35       100
# 12     Sunday    Espresso         45       150
# 13     Sunday       Latte         35       100

# %%
coffee_new['Units Sold'] = pd.to_numeric(coffee_new['Units Sold'])
coffee_new['New_Price'] = pd.to_numeric(coffee_new['New_Price'])

# %%
coffee_new.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 14 entries, 0 to 13
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     str
#  1   Coffee Type  14 non-null     str
#  2   Units Sold   14 non-null     int64
#  3   New_Price    14 non-null     int64
# dtypes: int64(2), str(2)
# memory usage: 755.0 bytes

# %%
coffee_new['Revenue']=coffee_new['Units Sold'] * coffee_new['New_Price']

# %%
coffee_new.head()
# Out:
#          Day Coffee Type  Units Sold  New_Price  Revenue
# 0     Monday    Espresso          25        150     3750
# 1     Monday       Latte          15        100     1500
# 2    Tuesday    Espresso          30        150     4500
# 3    Tuesday       Latte          20        100     2000
# 4  Wednesday    Espresso          35        150     5250

# %%
coffee_new['Revenue'].head(5).sum()
# Out:
# np.int64(17000)

# %%
coffee_new.rename(columns={'New_Price':'Price'}, inplace=True)

# %%
coffee_new.head()
# Out:
#          Day Coffee Type  Units Sold  Price  Revenue
# 0     Monday    Espresso          25    150     3750
# 1     Monday       Latte          15    100     1500
# 2    Tuesday    Espresso          30    150     4500
# 3    Tuesday       Latte          20    100     2000
# 4  Wednesday    Espresso          35    150     5250

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios_new=bios.copy()

# %%
bios_new['first_name']=bios_new['name'].str.split(' ').str[0]

# %%
bios_new.loc[bios_new['first_name']=='Keith']
# Out:
#         athlete_id               name   born_date     born_city  \
# 1897          1907       Keith Hanlon  1966-09-01           NaN
# 3505          3517      Keith Wallace  1961-03-29       Preston
# 6228          6255      Keith Hartley  1940-10-15     Vancouver
# 8898          8946        Keith Mwila  1966-01-01           NaN
# 12053        12118       Keith Hervey  1898-11-03        Fulham
# ...            ...                ...         ...           ...
# 99921       100722       Keith Carney  1970-02-03    Providence
# 102227      103168      Keith Beavers  1983-02-09        London
# 109900      111105  Keith Cumberpatch  1927-08-25  Christchurch
# 115973      117348    Keith Sanderson  1975-02-02      Plymouth
# 122121      124176     Keith Ferguson  1979-09-07          Sale
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 1897                 NaN          NaN        Ireland        NaN        NaN
# ...

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name
# 0  1960-10-02  Jean-François
# 1         NaN         Arnaud
# 2  1994-07-17           Jean
# 3  1978-03-20        Jacques
# 4  1930-07-25         Albert

# %%
bios_new['born_datetime']=pd.to_datetime(bios_new['born_date']).dt.year.astype('Int64')

# %%
bios_new[['name','born_datetime']]
# Out:
#                          name  born_datetime
# 0       Jean-François Blanchy           1886
# 1              Arnaud Boetsch           1969
# 2                Jean Borotra           1898
# 3             Jacques Brugnon           1895
# 4                Albert Canet           1878
# ...                       ...            ...
# 145495      Polina Luchnikova           2002
# 145496    Valeriya Merkusheva           1999
# 145497        Yuliya Smirnova           1998
# 145498         André Foussard           1899
# 145499          Bill Phillips           1913
#
# [145500 rows x 2 columns]

# %%
bios_new.to_csv('./data/bios_new.csv', index=False)

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios_new['height_category']=(bios_new['height_cm'].apply(lambda x : 'short' if x<165 else('average' if x < 185 else 'Tall')))

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
def categorize_athlete(row):
    if row['height_cm']<175 and row['weight_kg']<70:
        return 'lightweight'
    elif row['height_cm']<185 and row['weight_kg']<=85:
        return 'Midweight'
    else:
        return 'Heavyweight'

bios_new['Cateogry']=bios_new.apply(categorize_athlete, axis=1)

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name  born_datetime height_category     Cateogry
# 0  1960-10-02  Jean-François           1886            Tall  Heavyweight
# ...

# %%
nocs=pd.read_csv('./data/noc_regions.csv')

# %%
nocs.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
bios_new=pd.merge(bios, nocs, left_on='born_country', right_on='NOC',how='left')

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date NOC_y  region notes
# 0  1960-10-02   FRA  France   NaN
# 1         NaN   FRA  France   NaN
# 2  1994-07-17   FRA  France   NaN
# 3  1978-03-20   FRA  France   NaN
# ...

# %%
bios_new.loc[(bios_new['NOC_x'])!=(bios_new['region'])]
# Out:
#         athlete_id                 name   born_date         born_city  \
# 4                5         Albert Canet  1878-04-17        Wandsworth
# 12              13            J. Defert         NaN               NaN
# 13              14       Étienne Durand         NaN               NaN
# 16              17           Guy Forget  1965-01-04        Casablanca
# 27              28   Guy, Baron Lejeune         NaN               NaN
# ...            ...                  ...         ...               ...
# 145491      149218        Matthew Wepke  1989-12-05               NaN
# 145493      149220   Landysh Falyakhova  1998-08-31  Dva Polya Artash
# 145495      149222    Polina Luchnikova  2002-01-30             Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20   Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08            Kotlas
#
#                  born_region born_country    NOC_x  height_cm  weight_kg  \
# ...

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
usa=bios[bios['born_country']=='USA'].copy()
gbr=bios[bios['born_country']=='GBR'].copy()

# %%
new_df=pd.concat([usa,gbr])

# %%
new_df.tail()
# Out:
#         athlete_id                name   born_date     born_city born_region  \
# 144811      148512  Benjamin Alexander  1983-05-08        London     England
# 144815      148517       Ashley Watson  1993-10-28  Peterborough     England
# 145005      148716     Peder Kongshaug  2001-08-13     Wimbledon     England
# 145319      149041          Axel Brown  1992-04-02     Harrogate     England
# 145388      149111      Jean-Luc Baker  1993-10-07       Burnley     England
#
#        born_country                  NOC  height_cm  weight_kg died_date
# 144811          GBR              Jamaica        NaN        NaN       NaN
# 144815          GBR              Jamaica        NaN        NaN       NaN
# 145005          GBR               Norway      184.0       86.0       NaN
# 145319          GBR  Trinidad and Tobago        NaN        NaN       NaN
# 145388          GBR        United States        NaN        NaN       NaN

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price
# 0     Monday    Espresso          25   4.99
# 1     Monday       Latte          15   4.99
# 2    Tuesday    Espresso          30   4.99
# 3    Tuesday       Latte          20   4.99
# 4  Wednesday    Espresso          35   4.99

# %%
coffee['Units Sold'] = coffee['Units Sold'].astype(float)
coffee.loc[[0,1], 'Units Sold'] = np.nan

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price
# 0      Monday    Espresso         NaN   4.99
# 1      Monday       Latte         NaN   4.99
# 2     Tuesday    Espresso        30.0   4.99
# 3     Tuesday       Latte        20.0   4.99
# 4   Wednesday    Espresso        35.0   4.99
# 5   Wednesday       Latte        25.0   4.99
# 6    Thursday    Espresso        40.0   4.99
# 7    Thursday       Latte        30.0   4.99
# 8      Friday    Espresso        45.0   4.99
# 9      Friday       Latte        35.0   4.99
# 10   Saturday    Espresso        45.0   4.99
# 11   Saturday       Latte        35.0   4.99
# 12     Sunday    Espresso        45.0   4.99
# 13     Sunday       Latte        35.0   4.99

# %%
coffee.isna().sum()
# Out:
# Day            0
# Coffee Type    0
# Units Sold     2
# Price          0
# dtype: int64

# %%
coffee=coffee.fillna(coffee['Units Sold'].mean())

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price
# 0      Monday    Espresso        35.0   4.99
# 1      Monday       Latte        35.0   4.99
# 2     Tuesday    Espresso        30.0   4.99
# 3     Tuesday       Latte        20.0   4.99
# 4   Wednesday    Espresso        35.0   4.99
# 5   Wednesday       Latte        25.0   4.99
# 6    Thursday    Espresso        40.0   4.99
# 7    Thursday       Latte        30.0   4.99
# 8      Friday    Espresso        45.0   4.99
# 9      Friday       Latte        35.0   4.99
# 10   Saturday    Espresso        45.0   4.99
# 11   Saturday       Latte        35.0   4.99
# 12     Sunday    Espresso        45.0   4.99
# 13     Sunday       Latte        35.0   4.99

# %%
coffee_new.head()
# Out:
#          Day Coffee Type  Units Sold  Price  Revenue
# 0     Monday    Espresso          25    150     3750
# 1     Monday       Latte          15    100     1500
# 2    Tuesday    Espresso          30    150     4500
# 3    Tuesday       Latte          20    100     2000
# 4  Wednesday    Espresso          35    150     5250

# %%
coffee_new['Units Sold']=coffee_new['Units Sold'].astype(float)

# %%
coffee_new.loc[3:6,'Units Sold']=np.nan

# %%
coffee_new.head()
# Out:
#          Day Coffee Type  Units Sold  Price  Revenue
# 0     Monday    Espresso        25.0    150     3750
# 1     Monday       Latte        15.0    100     1500
# 2    Tuesday    Espresso        30.0    150     4500
# 3    Tuesday       Latte         NaN    100     2000
# 4  Wednesday    Espresso         NaN    150     5250

# %%
coffee_new['Units Sold']=coffee_new['Units Sold'].interpolate()

# %%
coffee_new
# Out:
#           Day Coffee Type  Units Sold  Price  Revenue
# 0      Monday    Espresso        25.0    150     3750
# 1      Monday       Latte        15.0    100     1500
# 2     Tuesday    Espresso        30.0    150     4500
# 3     Tuesday       Latte        30.0    100     2000
# 4   Wednesday    Espresso        30.0    150     5250
# 5   Wednesday       Latte        30.0    100     2500
# 6    Thursday    Espresso        30.0    150     6000
# 7    Thursday       Latte        30.0    100     3000
# 8      Friday    Espresso        45.0    150     6750
# 9      Friday       Latte        35.0    100     3500
# 10   Saturday    Espresso        45.0    150     6750
# 11   Saturday       Latte        35.0    100     3500
# 12     Sunday    Espresso        45.0    150     6750
# 13     Sunday       Latte        35.0    100     3500

# %%
coffee_new.loc[[3,4],'Units Sold']=np.nan

# %%
coffee_new=coffee_new.dropna()

# %%
coffee_new
# Out:
#           Day Coffee Type  Units Sold  Price  Revenue
# 0      Monday    Espresso        25.0    150     3750
# 1      Monday       Latte        15.0    100     1500
# 2     Tuesday    Espresso        30.0    150     4500
# 5   Wednesday       Latte        30.0    100     2500
# 6    Thursday    Espresso        30.0    150     6000
# 7    Thursday       Latte        30.0    100     3000
# 8      Friday    Espresso        45.0    150     6750
# 9      Friday       Latte        35.0    100     3500
# 10   Saturday    Espresso        45.0    150     6750
# 11   Saturday       Latte        35.0    100     3500
# 12     Sunday    Espresso        45.0    150     6750
# 13     Sunday       Latte        35.0    100     3500

# %%
coffee_new[coffee_new['Units Sold'].isna()]
# Out:
# Empty DataFrame
# Columns: [Day, Coffee Type, Units Sold, Price, Revenue]
# Index: []

# %%
coffee_new[coffee_new['Units Sold'].notna()]
# Out:
#           Day Coffee Type  Units Sold  Price  Revenue
# 0      Monday    Espresso        25.0    150     3750
# 1      Monday       Latte        15.0    100     1500
# 2     Tuesday    Espresso        30.0    150     4500
# 5   Wednesday       Latte        30.0    100     2500
# 6    Thursday    Espresso        30.0    150     6000
# 7    Thursday       Latte        30.0    100     3000
# 8      Friday    Espresso        45.0    150     6750
# 9      Friday       Latte        35.0    100     3500
# 10   Saturday    Espresso        45.0    150     6750
# 11   Saturday       Latte        35.0    100     3500
# 12     Sunday    Espresso        45.0    150     6750
# 13     Sunday       Latte        35.0    100     3500

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios['born_city'].value_counts()
# Out:
# born_city
# Budapest            1378
# Moskva (Moscow)      883
# Oslo                 708
# Stockholm            629
# Praha (Prague)       600
#                     ...
# Tsivilsk               1
# Roth                   1
# Romoos                 1
# Dva Polya Artash       1
# Dulwich Hill           1
# Name: count, Length: 22368, dtype: int64

# %%
bios[bios['born_country']=='USA']['born_region'].value_counts()
# Out:
# born_region
# California              1634
# New York                 990
# Illinois                 585
# Pennsylvania             530
# Massachusetts            530
# New Jersey               381
# Texas                    368
# Minnesota                365
# Ohio                     328
# Michigan                 319
# Washington               240
# Florida                  235
# Wisconsin                209
# Colorado                 207
# Connecticut              156
# Indiana                  150
# Oregon                   132
# Georgia                  129
# Virginia                 121
# Maryland                 117
# District of Columbia     107
# Iowa                     102
# Hawaiʻi                   95
# Kansas                    94
# Oklahoma                  93
# Louisiana                 92
# Utah                      91
# Missouri                  91
# North Carolina            86
# Arizona                   83
# New Hampshire             83
# ...

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price
# 0      Monday    Espresso        35.0   4.99
# 1      Monday       Latte        35.0   4.99
# 2     Tuesday    Espresso        30.0   4.99
# 3     Tuesday       Latte        20.0   4.99
# 4   Wednesday    Espresso        35.0   4.99
# 5   Wednesday       Latte        25.0   4.99
# 6    Thursday    Espresso        40.0   4.99
# 7    Thursday       Latte        30.0   4.99
# 8      Friday    Espresso        45.0   4.99
# 9      Friday       Latte        35.0   4.99
# 10   Saturday    Espresso        45.0   4.99
# 11   Saturday       Latte        35.0   4.99
# 12     Sunday    Espresso        45.0   4.99
# 13     Sunday       Latte        35.0   4.99

# %%
coffee.groupby(['Coffee Type', 'Day'])['Units Sold'].mean()
# Out:
# Coffee Type  Day
# Espresso     Friday       45.0
#              Monday       35.0
#              Saturday     45.0
#              Sunday       45.0
#              Thursday     40.0
#              Tuesday      30.0
#              Wednesday    35.0
# Latte        Friday       35.0
#              Monday       35.0
#              Saturday     35.0
#              Sunday       35.0
#              Thursday     30.0
#              Tuesday      20.0
#              Wednesday    25.0
# Name: Units Sold, dtype: float64

# %%
coffee.groupby(['Coffee Type','Day']).agg({'Units Sold':'sum', 'Price':'mean'})
# Out:
#                        Units Sold  Price
# Coffee Type Day
# Espresso    Friday           45.0   4.99
#             Monday           35.0   4.99
#             Saturday         45.0   4.99
#             Sunday           45.0   4.99
#             Thursday         40.0   4.99
#             Tuesday          30.0   4.99
#             Wednesday        35.0   4.99
# Latte       Friday           35.0   4.99
#             Monday           35.0   4.99
#             Saturday         35.0   4.99
#             Sunday           35.0   4.99
#             Thursday         30.0   4.99
#             Tuesday          20.0   4.99
#             Wednesday        25.0   4.99

# %%
coffee_new
# Out:
#           Day Coffee Type  Units Sold  Price  Revenue
# 0      Monday    Espresso        25.0    150     3750
# 1      Monday       Latte        15.0    100     1500
# 2     Tuesday    Espresso        30.0    150     4500
# 5   Wednesday       Latte        30.0    100     2500
# 6    Thursday    Espresso        30.0    150     6000
# 7    Thursday       Latte        30.0    100     3000
# 8      Friday    Espresso        45.0    150     6750
# 9      Friday       Latte        35.0    100     3500
# 10   Saturday    Espresso        45.0    150     6750
# 11   Saturday       Latte        35.0    100     3500
# 12     Sunday    Espresso        45.0    150     6750
# 13     Sunday       Latte        35.0    100     3500

# %%
pivot=coffee_new.pivot(columns='Coffee Type', index='Day', values='Revenue')

# %%
pivot
# Out:
# Coffee Type  Espresso   Latte
# Day
# Friday         6750.0  3500.0
# Monday         3750.0  1500.0
# Saturday       6750.0  3500.0
# Sunday         6750.0  3500.0
# Thursday       6000.0  3000.0
# Tuesday        4500.0     NaN
# Wednesday         NaN  2500.0

# %%
pivot.loc['Monday','Latte']
# Out:
# np.float64(1500.0)

# %%
pivot.sum()
# Out:
# Coffee Type
# Espresso    34500.0
# Latte       17500.0
# dtype: float64

# %%
pivot.sum(axis=1)
# Out:
# Day
# Friday       10250.0
# Monday        5250.0
# Saturday     10250.0
# Sunday       10250.0
# Thursday      9000.0
# Tuesday       4500.0
# Wednesday     2500.0
# dtype: float64

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios['born_date']=pd.to_datetime(bios['born_date'])
bios['born_year']=bios['born_date'].dt.year
bios['month_born']=bios['born_date'].dt.month
bios.groupby([bios['born_year'],bios['month_born']])['name'].count().reset_index().sort_values('name',ascending=0)
# Out:
#       born_year  month_born  name
# 1437     1970.0         1.0   239
# 1461     1972.0         1.0   229
# 1629     1986.0         1.0   227
# 1497     1975.0         1.0   227
# 1617     1985.0         1.0   225
# ...         ...         ...   ...
# 95       1857.0         5.0     1
# 96       1857.0         7.0     1
# 97       1857.0         8.0     1
# 98       1857.0         9.0     1
# 1884     2009.0         1.0     1
#
# [1885 rows x 3 columns]
